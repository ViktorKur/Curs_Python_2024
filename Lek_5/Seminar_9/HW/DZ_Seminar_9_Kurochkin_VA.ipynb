# %% [markdown]
# Набор рекламных данных, показывающих, щёлкнул ли конкретный пользователь рекламу на сайте компании или нет. Состоит из двух разных файлов: advertising_1.csv, advertising_2.csv.
#
# Описание столбцов датасета:
#
# ● Number:Номерпользователя всистеме.
#
# ● Daily Time Spent on Site: Среднее ежедневное время нахождения пользователя на сайте в минутах.
#
# ● Daily Internet Usage: Среднее ежедневное время нахождения пользователя в интернете в минутах.
#
# ● AdTopicLine: Заголовок рекламного объявления.
#
# ● Clicked on Ad: Кликнул пользователь на рекламу или нет.

# %% [markdown]
# Задание 1. Загрузите таблицу из файла advertising_1.csv и сохраните её в датафрейм adv1_df. Укажите в качестве индекса столбец Number. Выведите на экран первые десять строк.

# %%
import pandas as pds
adv1_df = pds.read_csv('Python_Seminars/advertising_1.csv')
adv1_df = adv1_df.set_index('Number')

# %%
adv1_df.head(10)
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# 11                         88.91                208.36
# 12                           NaN                131.76
# 13                         74.53                   NaN
# 14                         69.88                183.82
# 15                         47.64                122.02
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# 9               Robust logistical utilization              0
# ...

# %% [markdown]
# Задание 2. Выведите размер датафрейма adv1_df и cреднее ежедневное время нахождения в интернете пользователя под номером 8.

# %%
adv1_df.shape
# Out:
# (500, 4)

# %%
adv1_df
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# ...                          ...                   ...
# 525                        46.61                136.18
# 526                        63.26                120.46
# 527                        79.16                202.90
# 528                        67.94                128.16
# 529                        79.91                230.18
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# ...

# %%
adv1_df.loc[8, 'Daily Internet Usage']
# Out:
# 245.89

# %% [markdown]
# Задание 3. Загрузите таблицу из файла advertising_2.csv и сохраните её в датафрейм adv2_df. Укажите в качестве индекса стоблец Number. Выведите на экран строки для пользователей с номерами с 533-го по 536-й.

# %%
adv2_df = pds.read_csv('Python_Seminars/advertising_2.csv', index_col='Number')
adv2_df.loc[533:536]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1
